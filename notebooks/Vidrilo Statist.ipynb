# %% [markdown]
# # Sacamos la informacion estadisticas de los dataset de vidrilo
#
# Notebook que nos sirve para la memoria vamos a sacar estadisticas de los distintos dataset para ver que tamaño y ejemplos se generan

# %%
import sys
sys.path.insert(0, "../lib")
import numpy as np
import matplotlib.pyplot as plt
import sampling_util as smpl
from collections import Counter
# %matplotlib inline

# %%
path="/vol/pfc/data/datasets/Sequence1"
data=[int(i[1]) for i in smpl._load_file(path)]

# %%
c=Counter(data)

# %% [raw]
# np.array(c.keys())-1
#
# class_labels=['Corridor','Hall','ProfessorOffice','StudentOffice','TechnicalRoom','Toilet'
#               ,'SecretaryOffice','VideoConferenceRoom','Warehouse','ElevatorArea']
#
# np.array(class_labels)[]

# %%
c.values()
# Out:
# [1333, 103, 124, 155, 136, 121, 98, 149, 70, 100]

# %%
plt.bar(np.array(c.keys())-1, c.values(), 1)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-35-169da11bb344> in <module>()
# ----> 1 plt.bar(np.array(class_labels)[np.array(c.keys())-1], c.values(), 1)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, data, **kwargs)
#    2641     try:
#    2642         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2643                      **kwargs)
#    2644     finally:
#    2645         ax.hold(washold)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# ...

# %%
seq="Secuence1"
f = plt.figure(figsize=(6,4 ))
f.suptitle(seq+' distribution ', fontsize=12, fontweight='bold')
ax = f.add_axes([0.1, 0.1, 1, 0.8])
ax.bar(np.array(c.keys())-1, c.values(), align='center')
ax.set_xticks(np.array(c.keys())-1)
ax.set_xticklabels(class_labels,rotation=90)
f.show()

# %%
def generate_plot(seq):
    path="/vol/pfc/data/datasets/"+seq
    data=[int(i[1]) for i in smpl._load_file(path)]
    f = plt.figure(figsize=(6,4 ))
    f.suptitle(seq+' distribution ', fontsize=12, fontweight='bold')
    ax = f.add_axes([0.1, 0.1, 1, 0.8])
    ax.bar(np.array(c.keys())-1, c.values(), align='center')
    ax.set_xticks(np.array(c.keys())-1)
    ax.set_xticklabels(class_labels,rotation=90)
    f.show()

# %%
secuences=["Sequence1","Sequence2","Sequence3","Sequence4","Sequence5"]

for seq in secuences:
    generate_plot(seq)

# %%
path="/vol/pfc/data/datasets/Sequence5"

d = dict()

for i in smpl._load_file(path):
    
    if i[1] not in d:
        d[int(i[1])]=i[0]
         
print d
#od = collections.OrderedDict(sorted(d.items()))
#print od
#data=[int(i[1]) for i in smpl._load_file(path)]

import matplotlib.image as mpimg

d=["/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual258.png",
 "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual1567.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual1.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual91.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual1268.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual788.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual625.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual1890.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual2358.png",
  "/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual1524.png"]  
#  3
#   4
#  5
#  6
#  7
#  8
#  9
#  10
#/vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual1885.png 
for i in range(0,len(d)):
    fig =plt.figure(figsize=(6,6 ))
    print d[i]
    image = mpimg.imread(d[i])
    fig=plt.imshow(image) 
    plt.title(class_labels[i])
    fig.axes.get_xaxis().set_visible(False)
    fig.axes.get_yaxis().set_visible(False)
# Out:
# {1: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual8412.png', 2: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual7001.png', 3: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual1296.png', 4: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual5478.png', 5: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual4164.png', 6: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual1938.png', 7: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual3547.png', 8: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual4329.png', 9: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual8197.png', 10: '/vol/pfc/data/sequences/Sequence5/visualInformation/sequence5visual6448.png'}
# /vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual258.png
# /vol/pfc/data/sequences/Sequence1/visualInformation/sequence1visual1567.png
# ...
